# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\SANKET NICHAT\Desktop\sales_data_with_discounts.csv')

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df['BU'].unique()
# Out:
# array(['Mobiles', 'FMCG', 'Lifestyle'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# ## There are 6 numerical columns and 7 categorical columns in the above data and as per the boxplot below there are outliers in all the numerical columns.

# %%
Numerical=df.describe()
Numerical
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.boxplot()
plt.show
plt.tight_layout()

# %%
sc = StandardScaler()

scaled_df = pd.DataFrame(sc.fit_transform(Numerical), columns=Numerical.columns)

# %%
scaled_df.describe()
# Out:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  8.000000e+00  8.000000e+00       8.000000e+00           8.000000
# mean  -2.775558e-17 -2.775558e-17      -5.551115e-17           0.000000
# std    1.069045e+00  1.069045e+00       1.069045e+00           1.069045
# min   -4.233653e-01 -6.540530e-01      -6.892402e-01          -0.440455
# 25%   -4.045983e-01 -6.450082e-01      -6.610623e-01          -0.388527
# 50%   -3.984623e-01 -3.643555e-01      -3.753272e-01          -0.359877
# 75%   -3.465912e-01 -1.655744e-02       1.346308e-01          -0.341073
# max    2.640776e+00  2.504890e+00       2.489393e+00           2.643900
#
#        Discount Amount  Net Sales Value
# count     8.000000e+00     8.000000e+00
# mean     -5.551115e-17     2.775558e-17
# std       1.069045e+00     1.069045e+00
# min      -6.284065e-01    -6.851467e-01
# 25%      -5.799533e-01    -6.596717e-01
# 50%      -3.667920e-01    -3.794652e-01
# ...

# %%
scaled_df['Net Sales Value']
# Out:
# 0   -0.682966
# 1   -0.150905
# 2    0.130798
# 3   -0.685147
# 4   -0.651907
# 5   -0.608025
# 6    0.157196
# 7    2.490956
# Name: Net Sales Value, dtype: float64

# %%
scaled_df['Volume'].mean()
# Out:
# -2.7755575615628914e-17

# %%
df['Volume'].mean()
# Out:
# 5.066666666666666

# %% [markdown]
# ## We can see the difference in the mean of the column 'Volume' before and after standardisation.

# %% [markdown]
# ## Standardization of the columns is required to bring all the columns in one scale.It is important from machine learning point of view as the machine does not understand which column needs to be given more importance and it tends to consider those columns more important where the numbers are high.

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# ## Converting categorical columns in to Numerical column using one hot encoding method.

# %%
"""To put any data in to an algorithm the categorical columns need to be converted to a binary code i.e 0 and 1
as machine does not understand words or language expressions. To do this we can use the following get_dummies function from Pandas library.
It creates as many columns as the number of unique values in a categorical column and assigns a 0 or 1 value to each row"""
# Out:
# 'To put any data in to an algorithm the categorical columns need to be converted to a binary code i.e 0 and 1\nas machine does not understand words or language expressions. To do this we can use the following get_dummies function from Pandas library.\nIt creates as many columns as the number of unique values in a categorical column and assigns a 0 or 1 value to each row'

# %%
pd.get_dummies(data = df, columns=['BU'], dtype=int)
# Out:
#            Date       Day  SKU City  Volume  Brand       Model  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15  RealU       RU-10      12100
# 1    01-04-2021  Thursday  M02    C      10  RealU   RU-9 Plus      10100
# 2    01-04-2021  Thursday  M03    C       7   YouM       YM-99      16100
# 3    01-04-2021  Thursday  M04    C       6   YouM  YM-99 Plus      20100
# 4    01-04-2021  Thursday  M05    C       3   YouM      YM-98        8100
# ..          ...       ...  ...  ...     ...    ...         ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Jeera   M-Casuals       1300
# 446  15-04-2021  Thursday  L07    C       6   Viva   W-Western       2600
# 447  15-04-2021  Thursday  L08    C       2   Viva    W-Lounge       1600
# 448  15-04-2021  Thursday  L09    C       3  Jeera   M-Formals       1900
# 449  15-04-2021  Thursday  L10    C       1  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# ...

# %% [markdown]
# ## in the above example I have converted the BU categorical column in to three numerical column.
